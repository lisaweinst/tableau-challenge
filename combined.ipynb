# %%
import pandas as pd

# %%
citi201708_data = pd.read_csv("JC-201912-citibike-tripdata.csv", error_bad_lines=False)
citi201801_data = pd.read_csv("JC-202001-citibike-tripdata.csv", error_bad_lines=False)
citi201712_data = pd.read_csv("JC-202002-citibike-tripdata.csv", error_bad_lines=False)
citi201711_data = pd.read_csv("JC-202003-citibike-tripdata.csv", error_bad_lines=False)
citi201710_data = pd.read_csv("JC-202004-citibike-tripdata.csv", error_bad_lines=False)
citi201709_data = pd.read_csv("JC-202005-citibike-tripdata.csv", error_bad_lines=False)
citi201802_data = pd.read_csv("JC-202006-citibike-tripdata.csv", error_bad_lines=False)
citi201803_data = pd.read_csv("JC-202007-citibike-tripdata.csv", error_bad_lines=False)
citi201804_data = pd.read_csv("JC-202008-citibike-tripdata.csv", error_bad_lines=False)
citi201805_data = pd.read_csv("JC-202009-citibike-tripdata.csv", error_bad_lines=False)

# %%
citi_frames = [citi201708_data, citi201709_data, citi201710_data, citi201711_data, citi201712_data, citi201801_data, citi201802_data, citi201803_data, citi201804_data, citi201805_data]
citi_result = pd.concat(citi_frames)
citi_result.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1           416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2           294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3            97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4           286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
#
#    start station id start station name  start station latitude  \
# 0              3681           Grand St               40.715178
# 1              3195            Sip Ave               40.730897
# 2              3195            Sip Ave               40.730897
# 3              3202       Newport PATH               40.727224
# 4              3195            Sip Ave               40.730897
#
#    start station longitude  end station id  end station name  \
# 0               -74.037683            3198  Heights Elevator
# ...

# %%
citi_result.to_csv('Citi_Total_data.csv')
